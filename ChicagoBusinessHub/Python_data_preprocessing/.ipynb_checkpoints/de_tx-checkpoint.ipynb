# %%
import pandas as pd

df = pd.read_csv("C:/CSP584PROJCT/zipcacodecsv.csv")
df2=pd.read_csv("C:/CSP584PROJCT/Building_temp.csv")
# Out:
# C:\Users\ajayr\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,90,91,92,93,94,95,96,97,98,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df3=df2[["PERMIT#","PERMIT_TYPE","APPLICATION_START_DATE","ISSUE_DATE","LATITUDE","LONGITUDE"]]

# %%
df3["APPLICATION_START_DATE"]=df3["APPLICATION_START_DATE"].astype('datetime64[ns]')
df3=df3.sort_values('APPLICATION_START_DATE', ascending=False)
maindf=df3[:1000]
maindf
# Out:
#          PERMIT#                PERMIT_TYPE APPLICATION_START_DATE  \
# 4072   100851296  PERMIT - NEW CONSTRUCTION             2021-11-30
# 4067   100946087  PERMIT - NEW CONSTRUCTION             2021-11-29
# 4070   100927168  PERMIT - NEW CONSTRUCTION             2021-11-29
# 4059   100930670  PERMIT - NEW CONSTRUCTION             2021-11-24
# 4053   100949303  PERMIT - NEW CONSTRUCTION             2021-11-23
# ...          ...                        ...                    ...
# 267    100908916  PERMIT - NEW CONSTRUCTION             2021-03-18
# 3992   100909502  PERMIT - NEW CONSTRUCTION             2021-03-18
# 1867   100909368  PERMIT - NEW CONSTRUCTION             2021-03-18
# 25118  100908721  PERMIT - NEW CONSTRUCTION             2021-03-17
# 3230   100910472  PERMIT - NEW CONSTRUCTION             2021-03-17
#
#        ISSUE_DATE            LATITUDE           LONGITUDE zipcode
# 4072   11/30/2021        41.863984893  -87.62589624200001
# ...

# %%
from geopy.geocoders import Nominatim
maindf["zipcode"]=""
#df3 = df3.astype(str)
#df = df.astype(str)
#geolocator = Nominatim(user_agent="geoapiExercises")


for i in range(len(maindf)) :    
    Latitude=str(maindf.iloc[i, 4])
    Longitude=str(maindf.iloc[i, 5])
    
    if Latitude!="nan" and Longitude!="nan":

        location = geolocator.reverse(Latitude+","+Longitude)
        address = location.raw['address']
        zipcode = address.get('postcode')
        #print(dzipcode)
        maindf.iloc[i,6]=zipcode
# Out:
# <ipython-input-23-9d13719c83b2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maindf["zipcode"]=""
# C:\Users\ajayr\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df4 = pd.read_csv("C:/CSP584PROJCT/zip_ca.csv")
df4
# Out:
#      zipcode   communityareas
# 0      60647          HERMOSA
# 1      60619          PULLMAN
# 2      60625       NORTH PARK
# 3      60616  NEAR SOUTH SIDE
# 4      60649         WOODLAWN
# ..       ...              ...
# 198    60654             LOOP
# 199    60618         AVONDALE
# 200    60666            OHARE
# 201    60657         LAKEVIEW
# 202    60638           MIDWAY
#
# [203 rows x 2 columns]

# %%
maindf["community_area"]=""
maindf = maindf.astype(str)
df4 = df4.astype(str)

for i in range(len(maindf)) : 
    for j in range(len(df4)) : 
        #print(i,j)
        if maindf.iloc[i,6]==df4.iloc[j,0]:
            #print("j")
            maindf.iloc[i,7]=df4.iloc[j,1]
# Out:
# <ipython-input-29-934fd8ea3dd3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maindf["community_area"]=""
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# ...

# %%
maindf
# Out:
#          PERMIT#                PERMIT_TYPE APPLICATION_START_DATE  \
# 4072   100851296  PERMIT - NEW CONSTRUCTION             2021-11-30
# 4067   100946087  PERMIT - NEW CONSTRUCTION             2021-11-29
# 4070   100927168  PERMIT - NEW CONSTRUCTION             2021-11-29
# 4059   100930670  PERMIT - NEW CONSTRUCTION             2021-11-24
# 4053   100949303  PERMIT - NEW CONSTRUCTION             2021-11-23
# ...          ...                        ...                    ...
# 267    100908916  PERMIT - NEW CONSTRUCTION             2021-03-18
# 3992   100909502  PERMIT - NEW CONSTRUCTION             2021-03-18
# 1867   100909368  PERMIT - NEW CONSTRUCTION             2021-03-18
# 25118  100908721  PERMIT - NEW CONSTRUCTION             2021-03-17
# 3230   100910472  PERMIT - NEW CONSTRUCTION             2021-03-17
#
#        ISSUE_DATE            LATITUDE           LONGITUDE zipcode  \
# 4072   11/30/2021        41.863984893  -87.62589624200001      IL
# ...

# %%
maindf.to_csv('building_main.csv')

# %%
df10 = pd.read_csv("C:/CSP584PROJCT/zip.csv")
df20 = pd.read_csv("C:/CSP584PROJCT/poverty.csv")
df20
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                       1         Rogers Park                         7.7
# 1                       2          West Ridge                         7.8
# 2                       3              Uptown                         3.8
# 3                       4      Lincoln Square                         3.4
# 4                       5        North Center                         0.3
# ..                    ...                 ...                         ...
# 72                     73   Washington Height                         1.1
# 73                     74     Mount Greenwood                         1.0
# 74                     75         Morgan Park                         0.8
# 75                     76              O'Hare                         3.6
# 76                     77           Edgewater                         4.1
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# ...

# %%
df10["CHGOCA"] = df10["CHGOCA"].astype(int)
df20["Community Area Number"] = df20["Community Area Number"].astype(int)
df20["zipcode"]=""
for i in range(len(df20)) : 
    for j in range(len(df10)) : 
        #print(i,j)
        if df20.iloc[i,0]==df10.iloc[j,1]:
            #print("j")
            df20.iloc[i,9]=df10.iloc[j,0]

# %%
df20
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                       1         Rogers Park                         7.7
# 1                       2          West Ridge                         7.8
# 2                       3              Uptown                         3.8
# 3                       4      Lincoln Square                         3.4
# 4                       5        North Center                         0.3
# ..                    ...                 ...                         ...
# 72                     73   Washington Height                         1.1
# 73                     74     Mount Greenwood                         1.0
# 74                     75         Morgan Park                         0.8
# 75                     76              O'Hare                         3.6
# 76                     77           Edgewater                         4.1
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# ...

# %%
df20.to_csv('poverty_main.csv')

# %%
df_tx=pd.read_csv("C:/CSP584PROJCT/Taxi_Trips_2021.csv')

# %%
df_tx=df_tx.sort_values('Trip Start Timestamp', ascending=False)

# %%
df_tx
# Out:
#                                           Trip ID  \
# 3072476  fce82c138a421fd6e2a837845c988d97dadfae9a
# 3072448  20e190ff86f2206d23efe6f622022c80a68c8cb4
# 3072455  44438cc73e9224d06863cd8c81ac92e14179296d
# 3072454  3f85a2bf34222ba39d9e8cfceaf24ed31685d5a9
# 3072453  3ddb2f0ea882e2d2d63fe4ee4f08c95687d218c0
# ...                                           ...
# 88       1b3860ed6eeb0e6c0ecc8f29f12926656da07f7b
# 87       0b4955dbf03575ec3b7406a65f14c8963f3d4f3a
# 86       0472813b2adc49432007444d585556472f1ae04b
# 94       983177225eb98bf27fecb1dfd88401b604c0454a
# 93       7262542c5ce97bc2f990ea77899aee8e67f89654
#
#                                                    Taxi ID  \
# 3072476  961d0f7585bf4b5b5e6a35acea78a36dee71cab2323ab1...
# 3072448  e2252e4d7dd9d448ee731c06e763dbef7fbbc169bc0f67...
# 3072455  26a53f41b40ca4ec225a15ff55054c0a2d9e4a48341ce9...
# 3072454  df88e40cac8cf5e7da7fe4f619933719098adf6fe05741...
# 3072453  f98ae5e71fdda8806710af321dce58002146886c013f41...
# ...

# %%
df_tx_main=df_tx[:500000]

# %%
df_tx_main
# Out:
#                                           Trip ID  \
# 3072476  fce82c138a421fd6e2a837845c988d97dadfae9a
# 3072448  20e190ff86f2206d23efe6f622022c80a68c8cb4
# 3072455  44438cc73e9224d06863cd8c81ac92e14179296d
# 3072454  3f85a2bf34222ba39d9e8cfceaf24ed31685d5a9
# 3072453  3ddb2f0ea882e2d2d63fe4ee4f08c95687d218c0
# ...                                           ...
# 2575594  55b2be64229b6b6534be37623908b1d901a34e16
# 2575588  512a07e4f09cbb9074f3cdbe82c5058d5697ec32
# 2575589  5182f5e8dd786307fda78ac4a7b6a8b371444ae3
# 2575590  530b25a350c9ca6667cfff7ead215ff4b7a06b30
# 2575591  549fd3bcf842ddd433fe65d8b9f14a610c96d111
#
#                                                    Taxi ID  \
# 3072476  961d0f7585bf4b5b5e6a35acea78a36dee71cab2323ab1...
# 3072448  e2252e4d7dd9d448ee731c06e763dbef7fbbc169bc0f67...
# 3072455  26a53f41b40ca4ec225a15ff55054c0a2d9e4a48341ce9...
# 3072454  df88e40cac8cf5e7da7fe4f619933719098adf6fe05741...
# 3072453  f98ae5e71fdda8806710af321dce58002146886c013f41...
# ...

# %%
import numpy as np
df_tx_main=df_tx_main.replace(np.nan, 0)
df_tx_main["Pickup Community Area"] = df_tx_main["Pickup Community Area"].astype(int)

# %%
df_tx_main=df_tx_main.replace(np.nan, 0)
df_tx_main["Dropoff Community Area"] = df_tx_main["Dropoff Community Area"].astype(int)

# %%
df_ca = pd.read_csv("C:/CSP584PROJCT/zipcacodecsv.csv")
df_ca
# Out:
#     zip                  CA  Unnamed: 2  Unnamed: 3
# 0     1         ROGERS PARK         NaN         NaN
# 1     2          WEST RIDGE         NaN         NaN
# 2     3              UPTOWN         NaN         NaN
# 3     4      LINCOLN SQUARE         NaN         NaN
# 4     5        NORTH CENTER         NaN         NaN
# ..  ...                 ...         ...         ...
# 72   73  WASHINGTON HEIGHTS         NaN         NaN
# 73   74     MOUNT GREENWOOD         NaN         NaN
# 74   75         MORGAN PARK         NaN         NaN
# 75   76               OHARE         NaN         NaN
# 76   77           EDGEWATER         NaN         NaN
#
# [77 rows x 4 columns]

# %%
df_tx_main2=df_tx_main[["Trip ID","Taxi ID","Trip Start Timestamp","Trip End Timestamp","Trip Miles","Pickup Community Area","Dropoff Community Area","Trip Total","Company"]]
df_tx_main2
# Out:
#                                           Trip ID  \
# 3072476  fce82c138a421fd6e2a837845c988d97dadfae9a
# 3072448  20e190ff86f2206d23efe6f622022c80a68c8cb4
# 3072455  44438cc73e9224d06863cd8c81ac92e14179296d
# 3072454  3f85a2bf34222ba39d9e8cfceaf24ed31685d5a9
# 3072453  3ddb2f0ea882e2d2d63fe4ee4f08c95687d218c0
# ...                                           ...
# 2575594  55b2be64229b6b6534be37623908b1d901a34e16
# 2575588  512a07e4f09cbb9074f3cdbe82c5058d5697ec32
# 2575589  5182f5e8dd786307fda78ac4a7b6a8b371444ae3
# 2575590  530b25a350c9ca6667cfff7ead215ff4b7a06b30
# 2575591  549fd3bcf842ddd433fe65d8b9f14a610c96d111
#
#                                                    Taxi ID  \
# 3072476  961d0f7585bf4b5b5e6a35acea78a36dee71cab2323ab1...
# 3072448  e2252e4d7dd9d448ee731c06e763dbef7fbbc169bc0f67...
# 3072455  26a53f41b40ca4ec225a15ff55054c0a2d9e4a48341ce9...
# 3072454  df88e40cac8cf5e7da7fe4f619933719098adf6fe05741...
# 3072453  f98ae5e71fdda8806710af321dce58002146886c013f41...
# ...

# %%
# %%time
df_ca["zip"] = df_ca["zip"].astype(int)
df_tx_main2["pick_ca"]=""
df_tx_main2["drop_ca"]=""
for i in range(len(df_tx_main2)) : 
    for j in range(len(df_ca)) : 
        #print(i,j)
        if df_tx_main2.iloc[i,5]==df_ca.iloc[j,0]:
            #print("j")
            df_tx_main2.iloc[i,9]=df_ca.iloc[j,1]
        if df_tx_main2.iloc[i,6]==df_ca.iloc[j,0]:
            #print("j")
            df_tx_main2.iloc[i,10]=df_ca.iloc[j,1]
# Out:
# <timed exec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\ajayr\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_tx_main2
# Out:
#                                           Trip ID  \
# 3072476  fce82c138a421fd6e2a837845c988d97dadfae9a
# 3072448  20e190ff86f2206d23efe6f622022c80a68c8cb4
# 3072455  44438cc73e9224d06863cd8c81ac92e14179296d
# 3072454  3f85a2bf34222ba39d9e8cfceaf24ed31685d5a9
# 3072453  3ddb2f0ea882e2d2d63fe4ee4f08c95687d218c0
# ...                                           ...
# 2575594  55b2be64229b6b6534be37623908b1d901a34e16
# 2575588  512a07e4f09cbb9074f3cdbe82c5058d5697ec32
# 2575589  5182f5e8dd786307fda78ac4a7b6a8b371444ae3
# 2575590  530b25a350c9ca6667cfff7ead215ff4b7a06b30
# 2575591  549fd3bcf842ddd433fe65d8b9f14a610c96d111
#
#                                                    Taxi ID  \
# 3072476  961d0f7585bf4b5b5e6a35acea78a36dee71cab2323ab1...
# 3072448  e2252e4d7dd9d448ee731c06e763dbef7fbbc169bc0f67...
# 3072455  26a53f41b40ca4ec225a15ff55054c0a2d9e4a48341ce9...
# 3072454  df88e40cac8cf5e7da7fe4f619933719098adf6fe05741...
# 3072453  f98ae5e71fdda8806710af321dce58002146886c013f41...
# ...

# %%
df_tx_main2.to_csv('taxi_pred.csv')

# %%
df_tx_main2=df_tx_main2.rename(columns={"Trip ID": "trip_id", "Taxi ID": "taxi_id"})

# %%
df_tx_main2
# Out:
#                                           trip_id  \
# 3072476  fce82c138a421fd6e2a837845c988d97dadfae9a
# 3072448  20e190ff86f2206d23efe6f622022c80a68c8cb4
# 3072455  44438cc73e9224d06863cd8c81ac92e14179296d
# 3072454  3f85a2bf34222ba39d9e8cfceaf24ed31685d5a9
# 3072453  3ddb2f0ea882e2d2d63fe4ee4f08c95687d218c0
# ...                                           ...
# 2575594  55b2be64229b6b6534be37623908b1d901a34e16
# 2575588  512a07e4f09cbb9074f3cdbe82c5058d5697ec32
# 2575589  5182f5e8dd786307fda78ac4a7b6a8b371444ae3
# 2575590  530b25a350c9ca6667cfff7ead215ff4b7a06b30
# 2575591  549fd3bcf842ddd433fe65d8b9f14a610c96d111
#
#                                                    taxi_id  \
# 3072476  961d0f7585bf4b5b5e6a35acea78a36dee71cab2323ab1...
# 3072448  e2252e4d7dd9d448ee731c06e763dbef7fbbc169bc0f67...
# 3072455  26a53f41b40ca4ec225a15ff55054c0a2d9e4a48341ce9...
# 3072454  df88e40cac8cf5e7da7fe4f619933719098adf6fe05741...
# 3072453  f98ae5e71fdda8806710af321dce58002146886c013f41...
# ...

# %%
df_tx_main2=df_tx_main2.rename(columns={"Trip Start Timestamp": "trip_start_timestamp", "Trip End Timestamp": "trip_end_timestamp","Trip Miles": "trip_miles","Pickup Community Area": "pickup_community_area","Dropoff Community Area": "dropoff_community_area","Trip Total": "trip_total",})

# %%
df_tx_main2=df_tx_main2.rename(columns={"Company": "company",})

# %%
df_tx_main2
# Out:
#                                           trip_id  \
# 3072476  fce82c138a421fd6e2a837845c988d97dadfae9a
# 3072448  20e190ff86f2206d23efe6f622022c80a68c8cb4
# 3072455  44438cc73e9224d06863cd8c81ac92e14179296d
# 3072454  3f85a2bf34222ba39d9e8cfceaf24ed31685d5a9
# 3072453  3ddb2f0ea882e2d2d63fe4ee4f08c95687d218c0
# ...                                           ...
# 2575594  55b2be64229b6b6534be37623908b1d901a34e16
# 2575588  512a07e4f09cbb9074f3cdbe82c5058d5697ec32
# 2575589  5182f5e8dd786307fda78ac4a7b6a8b371444ae3
# 2575590  530b25a350c9ca6667cfff7ead215ff4b7a06b30
# 2575591  549fd3bcf842ddd433fe65d8b9f14a610c96d111
#
#                                                    taxi_id  \
# 3072476  961d0f7585bf4b5b5e6a35acea78a36dee71cab2323ab1...
# 3072448  e2252e4d7dd9d448ee731c06e763dbef7fbbc169bc0f67...
# 3072455  26a53f41b40ca4ec225a15ff55054c0a2d9e4a48341ce9...
# 3072454  df88e40cac8cf5e7da7fe4f619933719098adf6fe05741...
# 3072453  f98ae5e71fdda8806710af321dce58002146886c013f41...
# ...

# %%
df_tx_main2.to_csv('taxi_pred_m.csv')
