# %%
from fbprophet import Prophet
#model=Prophet()

# %% [markdown]
# # New Section

# %%
model.fit(df_oh)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
data_p=pd.DataFrame()
data_p["ds"]=selected_mi["Date of Count"]
data_p["y"]=selected_mi["Total Passing Vehicle Volume"]

# %%
data_p.head()
# Out:
#             ds      y
# 568 2021-08-02  71200
# 886 2021-10-23  59900
# 911 2021-09-12  58100
# 223 2021-09-12  41600
# 943 2021-11-14  30300

# %%
model=Prophet()
model.fit(data_p)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 13.

# %%
future = list()
date = '2021-12'
future.append([date])
for i in range(1, 13):
	date = '2022-%02d' % i
	future.append([date])
 
print(future)
# Out:
# [['2021-12'], ['2022-01'], ['2022-02'], ['2022-03'], ['2022-04'], ['2022-05'], ['2022-06'], ['2022-07'], ['2022-08'], ['2022-09'], ['2022-10'], ['2022-11'], ['2022-12']]

# %%
from pandas import DataFrame
from pandas import to_datetime
future = DataFrame(future)
future.columns = ['ds']
future['ds']= to_datetime(future['ds'])
forecast = model.predict(future)
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head())
# Out:
#           ds          yhat    yhat_lower    yhat_upper
# 0 2021-12-01  -9003.095830 -25880.930672   8906.902909
# 1 2022-01-01  61170.453435  42647.440851  80820.416657
# 2 2022-02-01  25601.208471   6581.172654  43463.801998
# 3 2022-03-01  26059.888970   7361.733776  44854.767862
# 4 2022-04-01  -7020.940605 -24583.097122  11515.853554

# %%
from matplotlib import pyplot
model.plot(forecast)
pyplot.show()

# %%
import pandas as pd
df_lk=pd.read_csv("taxi_lk.csv")
df_lp=pd.read_csv("taxi_lp.csv")
df_oh=pd.read_csv("taxi_oh.csv")
df_sc=pd.read_csv("taxi_sc.csv")
df_oh
df_oh['trip_date'] = pd.to_datetime(df_oh['trip_date'])
df_lp['trip_date'] = pd.to_datetime(df_lp['trip_date'])
df_sc['trip_date'] = pd.to_datetime(df_sc['trip_date'])
df_lk['trip_date'] = pd.to_datetime(df_lk['trip_date'])

df_oh=df_oh.sort_values(by=['trip_date'])
df_lp=df_lp.sort_values(by=['trip_date'])
df_sc=df_sc.sort_values(by=['trip_date'])
df_lk=df_lk.sort_values(by=['trip_date'])

df_oh=df_oh.rename(columns={"trip_date":"ds","traffic":"y"})
df_lk=df_lk.rename(columns={"trip_date":"ds","traffic":"y"})
df_sc=df_sc.rename(columns={"trip_date":"ds","traffic":"y"})
df_lp=df_lp.rename(columns={"trip_date":"ds","traffic":"y"})

df_lk
# Out:
#            ds     y
# 23 2021-09-30   290
# 4  2021-10-01  1237
# 19 2021-10-02  1148
# 25 2021-10-03  1141
# 24 2021-10-04   831
# 30 2021-10-05   789
# 8  2021-10-06   794
# 27 2021-10-07   893
# 6  2021-10-08  1302
# 5  2021-10-09  1202
# 20 2021-10-10  1098
# 1  2021-10-11   848
# 15 2021-10-12   850
# 14 2021-10-13   800
# 9  2021-10-14   926
# 2  2021-10-15  1223
# 22 2021-10-16  1327
# 16 2021-10-17  1187
# 26 2021-10-18   816
# 32 2021-10-19   870
# 13 2021-10-20   863
# 18 2021-10-21   960
# 7  2021-10-22  1193
# 28 2021-10-23  1196
# 21 2021-10-24  1129
# 11 2021-10-25   853
# 17 2021-10-26   786
# 31 2021-10-27   907
# 12 2021-10-28   981
# 0  2021-10-29  1179
# 10 2021-10-30  1396
# 3  2021-10-31  1261
# 29 2021-11-01     6

# %%
model1=Prophet()
model2=Prophet()
model3=Prophet()
model4=Prophet()

# %%
model1.fit(df_oh)
model2.fit(df_lk)
model3.fit(df_sc)
model4.fit(df_lp)

future_mo_lk=model2.make_future_dataframe(periods=120)
future_week_lk=model2.make_future_dataframe(periods=7)
future_da_lk=model2.make_future_dataframe(periods=1)

future_mo_lp=model4.make_future_dataframe(periods=120)
future_week_lp=model4.make_future_dataframe(periods=7)
future_da_lp=model4.make_future_dataframe(periods=1)

future_mo_sc=model3.make_future_dataframe(periods=120)
future_week_sc=model3.make_future_dataframe(periods=7)
future_da_sc=model3.make_future_dataframe(periods=1)

future_mo_oh=model1.make_future_dataframe(periods=120)
future_week_oh=model1.make_future_dataframe(periods=7)
future_da_oh=model1.make_future_dataframe(periods=1)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
pred_mo_lk=model2.predict(future_mo_lk)
pred_we_lk=model2.predict(future_week_lk)
pred_da_lk=model2.predict(future_da_lk)

pred_mo_lp=model4.predict(future_mo_lp)
pred_we_lp=model4.predict(future_week_lp)
pred_da_lp=model4.predict(future_da_lp)

pred_mo_sc=model3.predict(future_mo_sc)
pred_we_sc=model3.predict(future_week_sc)
pred_da_sc=model3.predict(future_da_sc)

pred_mo_oh=model1.predict(future_mo_oh)
pred_we_oh=model1.predict(future_week_oh)
pred_da_oh=model1.predict(future_da_oh)
pred_mo_lk
# Out:
#             ds        trend  ...  multiplicative_terms_upper         yhat
# 0   2021-09-30   948.692164  ...                         0.0   791.412052
# 1   2021-10-01   950.021933  ...                         0.0  1208.241969
# 2   2021-10-02   951.351702  ...                         0.0  1235.256323
# 3   2021-10-03   952.681471  ...                         0.0  1144.667560
# 4   2021-10-04   954.011240  ...                         0.0   652.259099
# ..         ...          ...  ...                         ...          ...
# 148 2022-02-25  1145.497970  ...                         0.0  1403.718006
# 149 2022-02-26  1146.827739  ...                         0.0  1430.732360
# 150 2022-02-27  1148.157507  ...                         0.0  1340.143597
# 151 2022-02-28  1149.487276  ...                         0.0   847.735135
# 152 2022-03-01  1150.817045  ...                         0.0  1005.309437
#
# [153 rows x 16 columns]

# %%
pred_mo_oh.to_csv('mon_oh2.csv')


pred_mo_lk.to_csv('mon_lk2.csv')



pred_mo_lp.to_csv('mon_lp2.csv')

pred_mo_sc.to_csv('mon_sc2.csv')

# %%
fig = model1.plot(pred_da_oh, xlabel='Date', ylabel='Traffic')
ax = fig.gca()
ax.set_title("OHARE TRAFFIC DAILY PREDICTION", size=24)
ax.set_xlabel("Date", size=24)
ax.set_ylabel("Traffic", size=24)
ax.tick_params(axis="x", labelsize=10)
ax.tick_params(axis="y", labelsize=10)

fig2 = model3.plot(pred_da_sc, xlabel='Date', ylabel='Traffic')
ax = fig2.gca()
ax.set_title("SOUTH CHICAGO TRAFFIC DAILY PREDICTION", size=24)
ax.set_xlabel("Date", size=24)
ax.set_ylabel("Traffic", size=24)
ax.tick_params(axis="x", labelsize=10)
ax.tick_params(axis="y", labelsize=10)

fig3 = model4.plot(pred_da_lp, xlabel='Date', ylabel='Traffic')
ax = fig3.gca()
ax.set_title("LOOP TRAFFIC DAILY PREDICTION", size=24)
ax.set_xlabel("Date", size=24)
ax.set_ylabel("Traffic", size=24)
ax.tick_params(axis="x", labelsize=10)
ax.tick_params(axis="y", labelsize=10)

fig4 = model2.plot(pred_da_lk, xlabel='Date', ylabel='Traffic')
ax = fig4.gca()
ax.set_title("LAKEVIEW TRAFFIC DAILY PREDICTION", size=24)
ax.set_xlabel("Date", size=24)
ax.set_ylabel("Traffic", size=24)
ax.tick_params(axis="x", labelsize=10)
ax.tick_params(axis="y", labelsize=10)
